# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings(action = 'ignore')
# %matplotlib inline

# 데이터 분할
from sklearn.model_selection import train_test_split, cross_val_score, StratifiedKFold

# 모델
from xgboost import XGBClassifier 
from lightgbm import LGBMClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression

# 파라미터 최적화
from bayes_opt import BayesianOptimization

# 평가지표
from sklearn.metrics import log_loss

# %%
train = pd.read_csv('train.csv', encoding = 'UTF-8')
test = pd.read_csv('test.csv', encoding = 'UTF-8')

# %%
data = pd.concat([train, test])

# %%
# SESS_DT 열의 type을 datetime으로 바꾸기
data['SESS_DT'] = pd.to_datetime(data['SESS_DT'], format= '%Y%m%d')

# TOT_SESS_HR_V 열의 ,를 지우고 int로 변환
data['TOT_SESS_HR_V'] = data['TOT_SESS_HR_V'].apply(lambda x : int(x.replace(',','')))

# PD_BRA_NM 열의 불필요한 특수문자 제거
data.PD_BRA_NM = data.PD_BRA_NM.apply(lambda x : x.replace('[','').replace(']',''))

# %%
train.PD_BRA_NM = train.PD_BRA_NM.apply(lambda x : x.replace('[','').replace(']',''))
test.PD_BRA_NM = test.PD_BRA_NM.apply(lambda x : x.replace('[','').replace(']',''))

# %%
p_level = 'PD_BRA_NM'  # 상품 분류 수준

# W2V 학습데이터가 부족하여 구매한 상품 목록으로부터 n배 oversampling을 수행
def oversample(x, n, seed=516):
    if n == 0:
        return list(x)
    uw = np.unique(x)
    bs = np.array([])
    np.random.seed(seed)
    for j in range(n):
        bs = np.append(bs, np.random.choice(uw, len(uw), replace=False))
    return list(bs)

train_corpus = list(train.groupby('CLNT_ID')[p_level].agg(oversample, 20))
test_corpus = list(test.groupby('CLNT_ID')[p_level].agg(oversample, 20))

num_features = 300 # 단어 벡터 차원 수
min_word_count = 5 # 최소 단어 수
context = 10 # 학습 윈도우(인접한 단어 리스트) 크기
downsampling = 1e-3

from gensim.models import word2vec

# 모델 학습
w2v = word2vec.Word2Vec(train_corpus, 
                        size = num_features, 
                        min_count = min_word_count,
                        window = context,
                        seed = 516, workers = 4, sg = 1, sample = downsampling)

w2v.init_sims(replace=True)

# %%
### Make features
# 구매상품에 해당하는 벡터의 평균/최소/최대 벡터를 feature로 만드는 전처리기
class EmbeddingVectorizer(object):
    def __init__(self, word2vec):
        self.word2vec = word2vec
        self.dim = num_features
    def fit(self, X):
        return self
    def transform(self, X):
        return np.array([
            np.hstack([np.mean([self.word2vec[w] for w in words if w in self.word2vec] or [np.zeros(self.dim)], axis=0)]) 
            for words in X
        ]) 

# W2V 기반 feature 생성
train_features = pd.DataFrame(EmbeddingVectorizer(w2v.wv).fit(train_corpus).transform(train_corpus))
test_features = pd.DataFrame(EmbeddingVectorizer(w2v.wv).transform(test_corpus))

train_features.columns = ['v' + f'{c+1:03d}' for c in train_features.columns]
test_features.columns = ['v' + f'{c+1:03d}' for c in test_features.columns]

# 학습용과 제출용 데이터로 분리
pd.concat([pd.DataFrame({'CLNT_ID': np.sort(train['CLNT_ID'].unique())}), train_features], axis=1).to_csv('brand2_w2v_train.csv', index=False)
pd.concat([pd.DataFrame({'CLNT_ID': np.sort(test['CLNT_ID'].unique())}), test_features], axis=1).to_csv('brand2_w2v_test.csv', index=False)

# %%
w2v.wv.most_similar(positive = "카파(스포츠)", topn = 10)
# Out:
# [('슈베카', 0.40943026542663574),
#  ('카파(프리미엄)', 0.38712936639785767),
#  ('흥국농산', 0.38711971044540405),
#  ('옥천농협', 0.377418577671051),
#  ('마지스체어', 0.3757610619068146),
#  ('행텐', 0.3752678632736206),
#  ('카파(잠실)', 0.3686213493347168),
#  ('베르베나스', 0.3674624264240265),
#  ('비에이치씨', 0.3660779595375061),
#  ('오도넬', 0.3547326326370239)]

# %%
list(data.PD_BRA_NM.unique())
# Out:
# ['아디다스(퍼포먼스)',
#  '아디다스(의류)',
#  '아디다스키즈(아동)',
#  '폴햄',
#  '바나나팜스',
#  '르꼬끄',
#  '노스페이스',
#  '헤링본',
#  '클립',
#  '라코스테(의류)',
#  '데상트',
#  '트렉스타',
#  '내셔널지오그래픽(남성)',
#  '아디다스',
#  '겐조 (향수)',
#  '히키스',
#  '미미앤디디',
#  '큐니걸스',
#  '슈에무라',
#  '바보사랑',
#  '스카이페스티발',
#  '듀듀(화장품)',
#  '데코뷰',
#  '탑텐',
#  '우아미가구',
#  '쿠키세븐',
#  '에뛰드하우스',
#  '솔로몬샵',
#  '꼬망스(아동)',
#  '노스페이스(레저)',
#  '르샤트라1802',
#  '베스트홈패션',
#  '첨이첨이',
#  '키엘',
#  '디스커버리',
#  '아디다스(슈즈)',
#  '나이키',
#  '샤넬',
#  '오조크',
#  '엘칸토',
#  '케이투',
#  '푸마(슈즈)',
#  '블루피오레',
#  '아이더',
#  '매그제이(MAGJAY)',
#  '이앤씨',
#  '윈',
#  '제이제이 지고트',
#  '세라블라썸',
#  '나이스클랍',
#  '케네스 레이디',
#  '아이잗컬렉션',
#  '르까프',
#  '허드슨테일러',
#  '플라스틱아일랜드',
#  '아디다스 언더웨어',
#  '록시',
#  '블루독',
#  '락앤락',
#  '마레스',
#  '씨씨콜렉트',
#  '맥',
#  '토모톰스',
#  '엘르 수영복',
#  '레노마수영복',
#  '에어워크주니어',
#  '데상트 스포츠',
#  '스위스런',
#  '크록스',
#  '지지피엑스',
#  '피닉스',
#  '산과들에',
#  '바바라(슈즈)',
#  '쉐모아',
#  '제이제이지고트',
#  '포커스',
#  '비키',
#  '고세(여성화)',
#  '리스트',
#  '손오공',
#  '스튜디오화이트',
#  '에이비에프지',
#  '정관장',
#  '유리아쥬',
#  '난닝구',
#  '뉴발란스(키즈)',
#  '레노마(셔츠)',
#  '레이지비(레저)',
#  '헤지스남성',
#  '헤지스 남성',
#  '코디갤러리 바이 에스티코',
#  '엠엘비키즈',
#  '하다라보',
#  '아토팜',
#  '컨택유',
#  '패션풀',
#  '피핀',
#  '폴로랄프로렌',
#  '피에르가르뎅(여성)',
#  '엘르(스카프)',
#  '엠씨',
#  '인디안',
#  '바이세정',
#  '캠브리지멤버스',
#  '브렌우드',
#  '엑스니스',
#  '스타일버즈',
#  '핑크시슬리',
#  '어반프랑',
#  '미치코런던',
#  '피에이티',
#  '올리비아로렌',
#  '행텐',
#  '피에르가르뎅(셔츠)',
#  '테이트',
#  '태창언더웨어',
#  '헨어스',
#  '빈폴아웃도어',
#  '하이시에라',
#  '티비제이',
#  '메쎄',
#  '프룹스',
#  '네파키즈',
#  '올 앤 썬드리',
#  '베스띠벨리',
#  '쉬즈미스',
#  '헤라',
#  '얼바인',
#  '라푸마',
#  '우바',
#  '플러스에스큐',
#  '아놀드파마 골프',
#  '크리스크리스티리얼맨',
#  '크로커다일 레이디',
#  '타미힐피거',
#  '빈폴',
#  '엠바골프',
#  '럭스골프',
#  '나이키(슈즈)',
#  '모드아이',
#  '데드라',
#  '까르뜨블랑슈남성',
#  '아리체',
#  '금강제화(남성)',
#  '케이스위스',
#  '제이디엑스',
#  '체스골프',
#  '루이까또즈(우양산)',
#  '와이케이편집샵',
#  '스테파넬',
#  '라푸마브이아이피',
#  '올리비아하슬러(여성)',
#  '화이트호스',
#  '무니베이직',
#  '컬리수',
#  '레노마키즈',
#  '휠라 키즈',
#  '휠라키즈',
#  '어반디케이',
#  '클리오',
#  '베네피트',
#  '시세이도',
#  '나스',
#  '클라이드',
#  '반에이크',
#  '온앤온',
#  '나이키수영복',
#  '임페리얼',
#  '리스트 레드라벨',
#  '갭',
#  '캘빈클라인 진',
#  '알엠케이',
#  '휠라(프리미엄)',
#  '에이지투웨니스',
#  '뉴트로지나',
#  '나이키골프',
#  '노스페이스키즈(아동)',
#  '퀸오브샌드',
#  '내추럴발란스',
#  '미미뚜뚜',
#  '닥터자르트',
#  '지오지아',
#  '에스티프렌치아이',
#  '포스트 커밍스텝',
#  '프리메라',
#  '디어달리아',
#  '시리즈(series)',
#  '포멜카멜레(슈즈)',
#  '록시땅',
#  '악녀일기',
#  '글로리룩',
#  '비달사순',
#  '디올',
#  '휴센',
#  '동서가구',
#  '클럽코코아',
#  '보웰',
#  '멜킨',
#  '판도라 다이어트',
#  '비오템',
#  '커스텀멜로우',
#  '티아이포맨',
#  '지오다노',
#  '레노마캐주얼',
#  '라코스테(여성)',
#  '앤드지',
#  '스와로브스키(주얼리)',
#  'SK-II',
#  '랩',
#  '뉴발란스(슈즈)',
#  'LG전자',
#  '엠폴햄',
#  '캉골',
#  '플라스틱아일랜드스토리',
#  '원더키드',
#  '미미월드',
#  '애스크 주니어',
#  '리바이스(키즈)',
#  '햇츠온',
#  '네이처리퍼블릭',
#  '불가리 향수',
#  '리바이스(바디웨어)',
#  '푸마 바디웨어',
#  '에스티 로더',
#  '플레이키즈프로',
#  '테팔',
#  '비와이씨',
#  '지미추',
#  '모노토노',
#  '만다리나덕',
#  '라인',
#  '에이비플러스',
#  '로엠',
#  '르크루제',
#  '빌레로이앤보흐',
#  '오직유기농',
#  '씨',
#  '레코브(여성의류)',
#  '샹티',
#  '쥬시쥬디',
#  '루미씨',
#  '인베스트',
#  '나인(NAIN)',
#  '에잇세컨즈',
#  '아가타파리',
#  '밀스튜디오',
#  '코스(KHOS)',
#  '마크모크',
#  '타미진(브이아이피)',
#  '밸리걸',
#  '에이치커넥트',
#  '게스(진)',
#  '제이스타일',
#  '부가티',
#  '까사부가티',
#  '엠엘비',
#  '메이비바니',
#  '비너스 아르보',
#  '트라이엄프',
#  '엘라호야 시크릿',
#  '비비씨 바이 비비안',
#  '타미힐피거 칠드런',
#  '오즈키즈',
#  '갭 키즈',
#  '아레나',
#  '제이코튼',
#  '엠알주니어',
#  '엠알키즈',
#  '설화수',
#  '타미진',
#  '스키즈',
#  '아레나(수영복)',
#  '아디다스 키즈',
#  '블랙야크(키즈)',
#  '티렌',
#  '메이크업포에버',
#  '닥스ACC',
#  '닥스맨',
#  '블루종',
#  '마인드브릿지',
#  '라보라',
#  '프로스펙스',
#  '라쉬반',
#  '판도라 바이 비비안',
#  '비너스 자스민',
#  '깨끗한나라',
#  '유기농본',
#  '판도라',
#  '비비안',
#  '뉴발란스',
#  '코어바디',
#  '아베다',
#  '조르지오 아르마니',
#  '입생로랑',
#  '로지텍',
#  '정샘물(화장품)',
#  '보니알렉스',
#  '오르시떼',
#  '잇미샤',
#  '원더브라(언더웨어)',
#  '에블린',
#  '엘르이너웨어',
#  '루이까또즈(셔츠)',
#  '휠라 골프',
#  '까스텔바작골프',
#  '헤지스골프',
#  '디즈니골프',
#  '데니스골프',
#  '비티알',
#  '엘르골프',
#  '쎄서미스트리트',
#  '알레어골프',
#  '레드페이스',
#  '육심원',
#  '뉴발란스(의류)',
#  '크록스(키즈)',
#  '슬레진저',
#  '페이퍼플레인키즈',
#  '콜맨',
#  '베네통키즈',
#  '머렐(레저)',
#  '솔방울',
#  '미쏘',
#  '한샘',
#  '티에스나인',
#  '아로마티카',
#  '조은',
#  '모니카룸',
#  '자유공간',
#  '아모레퍼시픽(생활)',
#  '마즈',
#  '헤지스 레이디스',
#  '헤지스레이디스',
#  '저스트리빙',
#  '해오름가구',
#  '로썸스튜디오',
#  'LOSSOMSTUDIO',
#  '크리넥스',
#  '에트로',
#  '왕자행거',
#  '하루메이비',
#  '보그',
#  '정관장.',
#  '로레알 파리',
#  '지방시',
#  '아디다스 오리지날',
#  '나트라케어',
#  '에어워크',
#  '케이에스몰',
#  '매긴',
#  '금찌더블랙',
#  '업타운홀릭',
#  '비엘르',
#  '바이너리원',
#  '루시다(의류)',
#  '스타일온미',
#  '라끄베르(화장품)',
#  '임블리(imvely)',
#  '라끄베르',
#  '라흐두뜨',
#  '딘트',
#  '미센스(여성의류)',
#  '제임스딘',
#  '바풀',
#  '아이엔지뷰티',
#  '텐바이텐',
#  '코스트코',
#  '르네브',
#  '블루비비 바이 비비안',
#  '그린너트',
#  '세인트마리',
#  '어바웃엘',
#  '코즈잇',
#  '논노스',
#  '테일러',
#  '가쯔',
#  '나이키(의류)',
#  '맥끌라니',
#  '롭스',
#  '에스티브랜뉴',
#  '밸롭',
#  '분홍코끼리',
#  '김영주 골프',
#  '제이제이나인',
#  '지니펫',
#  '엔터펫',
#  '포트메리온',
#  '꾸미바이트',
#  '코데즈컴바인',
#  '빌리프',
#  '아이오페',
#  '오휘',
#  '화이트',
#  '해피바스',
#  '블루독베이비',
#  '알로봇',
#  '래핑차일드',
#  '써모스',
#  '에고이스트',
#  '캘빈클라인언더웨어',
#  '포리빙',
#  '써스데이아일랜드',
#  '빈폴레이디스',
#  '애경',
#  '헨켈',
#  '페이퍼플레인',
#  '비씨비지',
#  '시슬리',
#  '프레쉬',
#  '일렉트로룩스',
#  '시슬리(화장품)',
#  '핏플랍',
#  '랑콤',
#  '예스',
#  '비너스',
#  '바비브라운',
#  '올삭스',
#  '에꼴리에',
#  '엠제이키즈',
#  '이랜드주니어',
#  '체이스컬트',
#  '예지미인',
#  '코즈니',
#  '토마톰스',
#  '아트박스',
#  '플라잉 타이거 코펜하겐',
#  '제이알주니어',
#  '이니스프리',
#  '앤와이코튼클럽',
#  '후앙스',
#  '온리프라이스',
#  '베지밀',
#  '정식품',
#  '슈퍼렉스',
#  '미니아트',
#  '바비쇼',
#  '피턴진',
#  '배스킨라빈스31',
#  '엔키노 키즈',
#  '나이키키즈',
#  '나이키 키즈',
#  '마몽드',
#  '트라이',
#  '비트로',
#  '루치펠로',
#  '크리오',
#  '위덴',
#  '비욘드',
#  '파나소닉(이미용)',
#  '키모니',
#  '오키즈',
#  '해리슨 옴므',
#  '엑토',
#  '퀵실버',
#  '스케쳐스',
#  '제이핑크',
#  '아모스프로페셔널',
#  '보슈아',
#  '스파클',
#  '밀라노바',
#  '다우니',
#  '모앤모',
#  '이반',
#  '빌리버스',
#  '위니아',
#  '프랑코페라로',
#  '토마토팩토리',
#  '엘리자베스아덴',
#  '오가니쉬',
#  '헬스익스텐션',
#  '르샵(LeShop)',
#  '르샵',
#  '마음심은',
#  '탑걸',
#  '화이트폭스',
#  '로한',
#  '복실이',
#  '펫토리아',
#  '벨라로사',
#  '나우(펫)',
#  '비지트인뉴욕',
#  '딩동펫',
#  '미스티에이치',
#  '패드',
#  '바찌',
#  '에이치옴므',
#  '모아시스템즈',
#  '더독',
#  '에바스',
#  '지이크',
#  '바자르',
#  '이라인',
#  '핫핑',
#  '블룸엣홈',
#  '던롭',
#  'UGIZ',
#  '오피스디포',
#  '보엠',
#  '비버리힐스폴로클럽',
#  '쏘아베(펫)',
#  '톰보이',
#  '쥬맥스',
#  '대웅모닝컴',
#  '타카오카컬렉션',
#  '엠블러',
#  '노스페이스화이트라벨(프리미엄)',
#  '파파야',
#  '맨잇슈트',
#  '슈펜',
#  '망고(MANGO)',
#  '피에르가르뎅_핸드백',
#  '페리페라',
#  '슈스토리',
#  '로벤탈',
#  '프라다',
#  '카시바디',
#  '고려은단',
#  'TS',
#  '탑이슈',
#  '24+',
#  '토프',
#  '디자인벤처스',
#  '케이엠',
#  '한미',
#  '올가홀푸드',
#  '플랜트로닉스',
#  '네파',
#  '싸이닉',
#  '베리떼',
#  '소이',
#  '쓰리엠',
#  '도담이',
#  '아쿠스',
#  '유솔(아동)',
#  '베이비(아동)',
#  '랠리',
#  '앳코너',
#  '엔젤링시크릿',
#  '닥터방기원',
#  '더나이스',
#  '삼립식품',
#  '쁘띠랭',
#  '엘프레리',
#  '퓨토',
#  '퓨토테라피',
#  '스완스',
#  '배내스템',
#  '탑텐키즈',
#  '까리제',
#  '제니코코',
#  '닥터아토',
#  '휠라티바',
#  '엑스웨이브',
#  '헌트키즈(아동)',
#  '영실업',
#  '더 퓨어',
#  '팬콧(키즈)',
#  '퓨어가닉',
#  '턴(TURN)',
#  '쿠기(수영복)',
#  '후그',
#  '포켓몬스터',
#  '헥스버그',
#  '실바니안패밀리',
#  '섀르반',
#  '톰키드',
#  '이사베이',
#  '코너샵',
#  '대신곤약',
#  'DHC',
#  '아벤느',
#  '아임웰',
#  '키스미',
#  '립합(LIPHOP)',
#  '아디다스 오리지널',
#  '미스터네이처',
#  '랜드로바(남성화)',
#  '피셔프라이스',
#  '헤지스ACC',
#  '마요',
#  '밴드에이드',
#  '마메든',
#  '버켄스탁',
#  '매일',
#  '일리윤',
#  '프레쉬라이트',
#  '엄브로',
#  '펫츠랜드',
#  '아쿠윈',
#  '크린랩',
#  '펀샵',
#  '해피락',
#  '뉴트리코어',
#  '넥스트',
#  '쁘리엘르',
#  '삐까삐까',
#  '블리블리',
#  '자연의품격',
#  '기라로쉬',
#  '밴웍스',
#  '코인코즈',
#  '가바',
#  '제이에스티나_핸드백',
#  '시크폭스',
#  '러브캣비쥬(주얼리)',
#  '플레이비츠',
#  '월튼키즈',
#  '쇼크업소버',
#  '크록스키즈',
#  '넷피엑스',
#  '마모트',
#  '아웃도어킹',
#  'BFL OUTDOOR',
#  '커터앤벅',
#  '오가닉맘',
#  '게스',
#  '티피링크',
#  '카카오 프렌즈',
#  '더리얼',
#  '더베터',
#  '미나그램',
#  '뉴트리오',
#  '베딩나라',
#  '샤본다마',
#  '바디엑스',
#  '헬렌스타인',
#  '온푸드',
#  '앤비마트',
#  '네파(아웃도어)',
#  '에이니',
#  '컨센서스',
#  '에이엔에프',
#  '레노마(손수건)',
#  '루이까또즈 스카프',
#  '타카타카',
#  '밀레',
#  '로베르타 디 카메리노',
#  '카시야',
#  '라이온코리아',
#  '행텐주니어',
#  '포에버21',
#  '비바하트',
#  '와이드앵글',
#  '풋조이',
#  '에어워크키즈',
#  '에이더블유케이',
#  '스파오',
#  '유솔',
#  '스킨푸드',
#  '페리페라(화장품)',
#  '이브스',
#  '트렌드세터',
#  '보이런던',
#  '빅야드',
#  '디즈니',
#  '헤지스',
#  '게스(언더웨어)',
#  '로베르따 디 까메리노(골프)',
#  '샌디스크',
#  '위즈홈',
#  '에드윈',
#  '칼미아',
#  '바디피트',
#  '클라란스',
#  '탠디(여성화)',
#  '이종임 김치',
#  '오야니(가방)',
#  '갤럭시펫',
#  '스킨스킨',
#  '보리보리',
#  '타요',
#  '기라로쉬(우양산)',
#  '아가타(우산)',
#  '도나블랑',
#  '비너스(스타킹)',
#  '밍크뮤',
#  'H스타일',
#  '나인스텝',
#  '아식스',
#  '마담4060',
#  '세주(완구)',
#  '메이커키즈',
#  '키친아트',
#  '로엠걸즈(아동)',
#  '레노마(모자)',
#  '제이케이',
#  '그룬트',
#  '스틸라',
#  '오르다셀렉샵',
#  '스킨푸드(화장품)',
#  '엘리자베스',
#  '린다',
#  '박홍근',
#  '프로텍트어베드',
#  '더틸버리',
#  '일칠사',
#  '버팔로',
#  '버팔로(캠핑)',
#  '뷰티끄',
#  '베베데코',
#  '카카모리',
#  '니베아',
#  '나디',
#  '카밀라',
#  'JW중외제약',
#  '미쟝센',
#  '미스사사',
#  '톰앤래빗',
#  '코디',
#  '로레알(백)',
#  '쓰리씨이',
#  '미샤',
#  '온더리버',
#  '유닉스',
#  '아메리칸투어리스터',
#  '신일',
#  '스위스밀리터리',
#  '웨스트우드',
#  '카파(스포츠)',
#  '카파(잠실)',
#  '셀덴(아동)',
#  '아놀드파마(양말)',
#  '리복 크로스핏',
#  '리복',
#  '더데이',
#  '하늘바라기',
#  '퍼실',
#  '홈앤하우스',
#  '무냐무냐',
#  '네오발란스',
#  '노스페이스(TNF)',
#  '원더풀라이프',
#  '메디앤스토리',
#  '소다',
#  '보타니컬테라피',
#  '넬리세제',
#  '레드씰',
#  '더바디샵',
#  '벨레다',
#  '투썸플레이스',
#  '챔프',
#  'AHC',
#  '카운테스마라(셔츠)',
#  '인트래블',
#  '르네 휘테르',
#  '르네휘테르',
#  '알페신(남성헤어)',
#  '리치파우치',
#  '마에스트로',
#  '탑앤탑',
#  '칼이쓰마',
#  '오리진스',
#  'XEEON',
#  '동원',
#  '블루라운지마에스트로',
#  '한일',
#  '브로이어블루(셔츠)',
#  '행복한바오밥',
#  '코리아보드게임즈',
#  '아디다스골프',
#  '셀퓨전씨',
#  '착한푸드',
#  '카카오프렌즈',
#  '카라코사',
#  '나즈나',
#  '아웃런',
#  '비즈제이',
#  '보브(의류)',
#  'FRED PERRY',
#  '기어엑스',
#  '알럽하우스',
#  '코렐코디네이츠',
#  '퍼니메이드',
#  '코니테일',
#  '리바디',
#  '트루폭시',
#  '타이틀리스트',
#  '제이크로우',
#  '고운',
#  '센카',
#  '시스맥스',
#  '기타',
#  '프렌치불',
#  '디노바시',
#  '파워풀엑스',
#  '플렉스파워',
#  '닥터영',
#  '로이드(주얼리)',
#  '건종',
#  '가베가족',
#  '오션글라스',
#  '모닝글로리',
#  '돔바슈즈',
#  '지에스25',
#  '웅진식품',
#  '씨유',
#  '스마스토어',
#  '보네이도',
#  '점프',
#  '닥스(우양산)',
#  '304160',
#  '샤바스',
#  '메트로시티(주얼리)',
#  '스타일빅걸',
#  '더샘',
#  '유한킴벌리',
#  '허그앤그로우',
#  '유팡',
#  '푸치',
#  '헬로키티',
#  '스퍼',
#  '유스마일',
#  '네일스네일',
#  '지프',
#  '돌체구스토',
#  '스메그',
#  '롯데칠성몰',
#  '857-05',
#  '108216',
#  '로얄알버트',
#  '가락상회',
#  '에뻬',
#  '헌트키즈',
#  '리틀뱅뱅',
#  '크리니크',
#  '홈스웰',
#  '인블리스',
#  '얌',
#  '크리비아',
#  '유노하나',
#  '마운틴스토리',
#  '코베아',
#  '피레스트',
#  '롯데식품관',
#  'VDL',
#  '미니소',
#  '라우쉬',
#  '모나미',
#  '106701',
#  '빅',
#  '아폴로',
#  '평화',
#  '토니모리',
#  '엘르(우양산)',
#  '올리빙',
#  '지스바이',
#  '벨리불리',
#  '마블(잡화)',
#  '인샤틴(우양산)',
#  '르꽁뚜아르뒤뱅',
#  '라우라 비아조띠',
#  '도시바',
#  '아이소이',
#  '프랜치캣',
#  '얌박스',
#  '래디어스',
#  '데일리라이크',
#  '하프 문 아이즈',
#  '베네통',
#  '네네덴트',
#  '여미터미',
#  '로트리',
#  '라덴트',
#  '아망떼',
#  'DERMA CLASSEN',
#  '더마클라센',
#  '엘리자벳',
#  '포래즈',
#  '시에로',
#  '삼진인터내셔널',
#  '올리브데올리브',
#  '세컨플로어',
#  '스테판조셉',
#  '디데무',
#  '드팜',
#  '코코리따',
#  '차앤박',
#  '아가방',
#  '질경이',
#  '박씨상방',
#  '라네즈',
#  '헤지스 키즈',
#  '헤지스키즈',
#  '닥스 키즈',
#  '비바텍',
#  '닥터지',
#  '비비안(스타킹)',
#  '리스테린',
#  '알도',
#  '리안뉴욕',
#  '슈미즈',
#  '스코노',
#  '농협홍삼한삼인',
#  '네이쳐리빙',
#  '이장님닷컴',
#  '우드밀리',
#  '창신리빙',
#  '세컨스킨',
#  '엘리카',
#  '니지 쥬얼리',
#  '풀무원',
#  '한율',
#  '프롬비',
#  '니코트',
#  '쿠비카',
#  '컬럼비아',
#  '맨즈베이직',
#  '앨빈클로',
#  '캐서린말란드리노',
#  '디키즈',
#  '버커루 브이아이피',
#  '다나한',
#  '한미마루',
#  '시크릿데이',
#  '송월타월',
#  '오랄비',
#  '옥스포드(완구)',
#  '트라이(속옷)',
#  '예작(셔츠)',
#  '넛츠팜',
#  '마더네스트',
#  '페이지플린',
#  '레노마',
#  '체리코코',
#  '에이와비',
#  '엘르(양말)',
#  '후아유',
#  '플루크',
#  '아트와이어',
#  '서빈',
#  '팜앤푸드',
#  '아날도바시니',
#  '앤더리빙',
#  '쿠기',
#  '에스쁘렌도',
#  '흄',
#  '엘아우어',
#  '코스타노바',
#  '쿠쿠',
#  '자연의미소',
#  '지엠에스',
#  '핀란디아',
#  '롯데시네마',
#  '코튼렛',
#  '빈',
#  '닥스키즈',
#  '휠라',
#  '튤립',
#  '모다까리나',
#  '마이스토',
#  '타투(선글라스)',
#  '피그먼트',
#  '아미마켓',
#  '헤드',
#  '키즈라인',
#  '타미힐피거여성',
#  '소보제화',
#  '숲',
#  '컴포트랩',
#  '닥스레이디스',
#  '오에스티',
#  '더아이잗(여성)',
#  '아디다스(키즈)',
#  '게스(키즈)',
#  '캐치웰',
#  '베스트리빙',
#  '라코스테스포츠',
#  '게스(진유니)',
#  '데일리원',
#  '이오스트',
#  '플레이텍스',
#  '스킨푸드(명품화장품)',
#  '오일릴리',
#  '클라비스',
#  '끌로에(향수)',
#  '순수연구소',
#  '실크테라피',
#  '끌로에 향수',
#  '버커루',
#  '키플링',
#  '비아모노',
#  '에프알제이',
#  '크리스제이',
#  '댑 코리아',
#  '밥스누',
#  '닥스(여성화)',
#  '노스페이스영',
#  '은성',
#  '러브필',
#  '프롬바이오',
#  '랩시리즈',
#  '랩 시리즈',
#  '모윰',
#  '에티튜드',
#  '엘리펀트이어스',
#  '더블하트',
#  '이고진',
#  '내셔널지오그래픽',
#  '네이처리퍼블릭(식품)',
#  '아쿠아티카',
#  ...]

# %%
target = pd.read_csv('cust_train.csv', encoding = 'UTF-8')
label = target.LABEL

# %%
train = pd.read_csv('brand2_w2v_train.csv', encoding = 'UTF-8')
test = pd.read_csv('brand2_w2v_test.csv', encoding = 'UTF-8')

X_train, X_val, y_train, y_val = train_test_split(train, label, test_size = 0.3, random_state = 516, stratify = label)

# %%
pbounds = {'n_estimators' : (50, 500),
           'learning_rate' : (0.01, 1.0),
           'max_depth' : (2, 10),
           'num_leaves' : (10, 200),
           'min_child_samples' : (20, 100),
           'min_child_weight' : (1, 15),
           'subsample' : (0.75, 0.95),
           'colsample_bytree' : (0.75, 0.95)}


def lgbm_opt(n_estimators, learning_rate, max_depth, num_leaves, min_child_samples, min_child_weight, subsample, colsample_bytree):
    
    
    params = {'n_estimators' : int(round(n_estimators)),
              'learning_rate': learning_rate,
              'max_depth' : int(round(max_depth)),
              'num_leaves' : int(round(num_leaves)),
              'min_child_samples' : int(round(min_child_samples)),
              'min_child_weight' : min_child_weight,
              'subsample': subsample,
              'colsample_bytree' : colsample_bytree,
              'n_jobs' : -1}
    
    lgbm = LGBMClassifier(**params)
    
    skfold = StratifiedKFold(n_splits = 4, shuffle = True, random_state = 516)
    
    score = cross_val_score(lgbm, X_train, y_train, cv = skfold, scoring = 'neg_log_loss', n_jobs=-1)
    
    return np.mean(score)

BO_lgbm = BayesianOptimization(f = lgbm_opt, pbounds = pbounds, random_state = 516)

BO_lgbm.maximize(init_points=30, n_iter=30)

max_params = BO_lgbm.max['params']
max_params['n_estimators'] = int(round(max_params['n_estimators']))
max_params['max_depth'] = int(round(max_params['max_depth']))
max_params['num_leaves'] = int(round(max_params['num_leaves']))
max_params['min_child_samples'] = int(round(max_params['min_child_samples']))
display(max_params)

# Step9. 최대화 하이퍼파라미터로 재학습
lgbm_tun = LGBMClassifier(**max_params)
lgbm_tun.fit(X_train, y_train)

skfold = StratifiedKFold(n_splits = 4, shuffle = True, random_state = 516)
scores = cross_val_score(lgbm_tun, X_val, y_val, cv = skfold, scoring = 'neg_log_loss', n_jobs=-1)

print(scores)
print(f'최대성능: {max(scores)}\n평균성능: {np.mean(scores)}')
# Out:
# |   iter    |  target   | colsam... | learni... | max_depth | min_ch... | min_ch... | n_esti... | num_le... | subsample |
# -------------------------------------------------------------------------------------------------------------------------
# |  1        | -1.336    |  0.9123   |  0.7113   |  3.45     |  76.68    |  16.06    |  435.0    |  140.1    |  0.789    |
# |  2        | -2.076    |  0.7878   |  0.8463   |  7.098    |  95.81    |  4.343    |  337.7    |  76.55    |  0.8719   |
# |  3        | -2.091    |  0.8565   |  0.7491   |  9.013    |  20.69    |  11.26    |  371.6    |  83.02    |  0.8451   |
# |  4        | -1.818    |  0.8397   |  0.4175   |  14.82    |  31.53    |  18.8     |  322.0    |  169.2    |  0.7549   |
# |  5        | -1.524    |  0.879    |  0.7114   |  4.6      |  98.35    |  7.472    |  293.0    |  184.6    |  0.8592   |
# |  6        | -1.287    |  0.9255   |  0.08759  |  7.357    |  66.69    |  1.212    |  196.0    |  201.3    |  0.8305   |
# |  7        | -1.58     |  0.7666   |  0.2404   |  10.82    |  49.52    |  14.19    |  455.8    |  104.1    |  0.8177   |
# |  8        | -1.522    |  0.9158   |  0.4006   |  12.5     |  114.5    |  8.863    |  155.8    |  99.16    |  0.9248   |
# |  9        | -1.246    |  0.8433   |  0.05106  |  4.72     |  58.52    |  16.61    |  436.3    |  11.1     |  0.9335   |
# |  10       | -1.378    |  0.9359   |  0.356    |  6.073    |  118.0    |  8.654    |  195.3    |  235.3    |  0.8047   |
# |  11       | -1.557    |  0.7652   |  0.4286   |  5.553    |  69.32    |  17.14    |  494.8    |  195.3    |  0.9073   |
# |  12       | -1.285    |  0.8046   |  0.6025   |  3.241    |  34.59    |  2.371    |  194.2    |  125.7    |  0.8522   |
# |  13       | -2.05     |  0.8573   |  0.8136   |  6.906    |  63.61    |  14.78    |  433.3    |  139.3    |  0.7571   |
# |  14       | -7.197    |  0.8111   |  0.9066   |  9.726    |  108.8    |  5.784    |  318.7    |  66.02    |  0.7574   |
# |  15       | -1.305    |  0.9476   |  0.2786   |  4.003    |  41.86    |  5.603    |  463.9    |  171.9    |  0.7593   |
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\bayes_opt\target_space.py in probe(self, params)
#     190         try:
# --> 191             target = self._cache[_hashable(x)]
#     192         except KeyError:
#
# KeyError: (0.7705617860949202, 0.5644869775686044, 10.631740794487216, 113.52448486051736, 14.61022706504392, 307.63298338454683, 123.46618107415848, 0.8319134549681996)
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-53-a0a70c82ee54> in <module>
#      32 BO_lgbm = BayesianOptimization(f = lgbm_opt, pbounds = pbounds, random_state = 516)
#      33
# ---> 34 BO_lgbm.maximize(init_points=30, n_iter=30)
#      35
#      36 max_params = BO_lgbm.max['params']
#
# ~\Anaconda3\lib\site-packages\bayes_opt\bayesian_optimization.py in maximize(self, init_points, n_iter, acq, kappa, kappa_decay, kappa_decay_delay, xi, **gp_params)
#     183                 iteration += 1
#     184
# --> 185             self.probe(x_probe, lazy=False)
#     186
#     187             if self._bounds_transformer:
#
# ~\Anaconda3\lib\site-packages\bayes_opt\bayesian_optimization.py in probe(self, params, lazy)
#     114             self._queue.add(params)
#     115         else:
# --> 116             self._space.probe(params)
#     117             self.dispatch(Events.OPTIMIZATION_STEP)
#     118
#
# ~\Anaconda3\lib\site-packages\bayes_opt\target_space.py in probe(self, params)
#     192         except KeyError:
#     193             params = dict(zip(self._keys, x))
# --> 194             target = self.target_func(**params)
#     195             self.register(x, target)
#     196         return target
#
# <ipython-input-53-a0a70c82ee54> in lgbm_opt(n_estimators, learning_rate, max_depth, num_leaves, min_child_samples, min_child_weight, subsample, colsample_bytree)
#      26     skfold = StratifiedKFold(n_splits = 4, shuffle = True, random_state = 516)
#      27
# ---> 28     score = cross_val_score(lgbm, X_train, y_train, cv = skfold, scoring = 'neg_log_loss', n_jobs=-1)
#      29
#      30     return np.mean(score)
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      70                           FutureWarning)
#      71         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 72         return f(**kwargs)
#      73     return inner_f
#      74
#
# ~\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py in cross_val_score(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch, error_score)
#     404                                 fit_params=fit_params,
#     405                                 pre_dispatch=pre_dispatch,
# --> 406                                 error_score=error_score)
#     407     return cv_results['test_score']
#     408
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      70                           FutureWarning)
#      71         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 72         return f(**kwargs)
#      73     return inner_f
#      74
#
# ~\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py in cross_validate(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch, return_train_score, return_estimator, error_score)
#     246             return_times=True, return_estimator=return_estimator,
#     247             error_score=error_score)
# --> 248         for train, test in cv.split(X, y, groups))
#     249
#     250     zipped_scores = list(zip(*scores))
#
# ~\Anaconda3\lib\site-packages\joblib\parallel.py in __call__(self, iterable)
#    1040
#    1041             with self._backend.retrieval_context():
# -> 1042                 self.retrieve()
#    1043             # Make sure that we get a last message telling us we are done
#    1044             elapsed_time = time.time() - self._start_time
#
# ~\Anaconda3\lib\site-packages\joblib\parallel.py in retrieve(self)
#     919             try:
#     920                 if getattr(self._backend, 'supports_timeout', False):
# --> 921                     self._output.extend(job.get(timeout=self.timeout))
#     922                 else:
#     923                     self._output.extend(job.get())
#
# ~\Anaconda3\lib\site-packages\joblib\_parallel_backends.py in wrap_future_result(future, timeout)
#     538         AsyncResults.get from multiprocessing."""
#     539         try:
# --> 540             return future.result(timeout=timeout)
#     541         except CfTimeoutError:
#     542             raise TimeoutError()
#
# ~\Anaconda3\lib\concurrent\futures\_base.py in result(self, timeout)
#     425                 return self.__get_result()
#     426
# --> 427             self._condition.wait(timeout)
#     428
#     429             if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# ~\Anaconda3\lib\threading.py in wait(self, timeout)
#     294         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     295             if timeout is None:
# --> 296                 waiter.acquire()
#     297                 gotit = True
#     298             else:
#
# KeyboardInterrupt:
